# %%
import pandas as pd

# %% [markdown]
# ## Reding a CSV file

# %%
data = pd.read_csv("employee.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.corr()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7568\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
data['MonthlyCharges'].mean()
# Out:
# 64.76169246059918

# %%
data['MonthlyCharges'].dtype
# Out:
# dtype('float64')

# %%
data['Churn']
data['Churn'].count()
# Out:
# 7043

# %%
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# ## usecols to select the columns and nrow to select the total number of rows

# %%
dataset = "employee.csv"
x = pd.read_csv(dataset, nrows = 7001 , usecols =['customerID','Contract','MonthlyCharges','TotalCharges','Churn'])
x.tail()
# Out:
#       customerID        Contract  MonthlyCharges TotalCharges Churn
# 6996  4174-LPGTI        One year           66.50       2728.6   Yes
# 6997  2523-EWWZL  Month-to-month           76.10       2093.4    No
# 6998  0928-XUTSN  Month-to-month           80.50       1011.8    No
# 6999  2108-XWMPY  Month-to-month           35.45       106.85   Yes
# 7000  0052-YNYOT        One year           20.55       1343.4    No

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
x = pd.read_csv(dataset, nrows = 7001 , usecols =[0,3,6])
x
# Out:
#       customerID Partner PhoneService
# 0     7590-VHVEG     Yes           No
# 1     5575-GNVDE      No          Yes
# 2     3668-QPYBK      No          Yes
# 3     7795-CFOCW      No           No
# 4     9237-HQITU      No          Yes
# ...          ...     ...          ...
# 6996  4174-LPGTI     Yes          Yes
# 6997  2523-EWWZL     Yes          Yes
# 6998  0928-XUTSN      No          Yes
# 6999  2108-XWMPY      No           No
# 7000  0052-YNYOT      No          Yes
#
# [7001 rows x 3 columns]

# %% [markdown]
# ## skiprows to skip the rows which are not required for the model

# %%
x = pd.read_csv(dataset, nrows = 7001 , usecols =[0,3,6] , skiprows= 1000)
x
# Out:
#       3234-VKACU   No  Yes
# 0     8357-EQXFO   No  Yes
# 1     1989-PRJHP  Yes  Yes
# 2     8120-JDCAM  Yes  Yes
# 3     8917-FAEMR   No  Yes
# 4     7047-YXDMZ   No  Yes
# ...          ...  ...  ...
# 6038  6840-RESVB  Yes  Yes
# 6039  2234-XADUH  Yes  Yes
# 6040  4801-JZAZL  Yes   No
# 6041  8361-LTMKD  Yes  Yes
# 6042  3186-AJIEK   No  Yes
#
# [6043 rows x 3 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.drop('User ID', axis =1, inplace = True)

# %%
gender = {'Male':1,'Female':0}
df['Gender'] = df['Gender'].map(gender)

# %%
x = df[['Gender','Age','EstimatedSalary']]
y = df['Purchased']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
 X_train.head()
# y_train
# X_test
# y_test
# Out:
#      Gender  Age  EstimatedSalary
# 92        1   26            15000
# 223       1   60           102000
# 234       0   38           112000
# 232       1   40           107000
# 377       0   42            53000

# %%
from sklearn.preprocessing import StandardScaler
scale  = StandardScaler()

# %%
scale.fit(X_train)
# Out:
# StandardScaler()

# %%
x_trained_scale = scale.transform(X_train)
x_test_scale = scale.transform(X_test)

# %%
scale.mean_
# Out:
# array([5.03571429e-01, 3.78642857e+01, 6.98071429e+04])

# %%
x_trained_scale
# Out:
# array([[ 0.99288247, -1.1631724 , -1.5849703 ],
#        [ 0.99288247,  2.17018137,  0.93098672],
#        [-1.00716855,  0.0133054 ,  1.22017719],
#        [ 0.99288247,  0.20938504,  1.07558195],
#        [-1.00716855,  0.40546467, -0.48604654],
#        [ 0.99288247, -0.28081405, -0.31253226],
#        [ 0.99288247,  0.99370357, -0.8330751 ],
#        [-1.00716855,  0.99370357,  1.8563962 ],
#        [-1.00716855,  0.0133054 ,  1.24909623],
#        [ 0.99288247, -0.86905295,  2.26126285],
#        [-1.00716855, -1.1631724 , -1.5849703 ],
#        [ 0.99288247,  2.17018137, -0.80415605],
#        [ 0.99288247, -1.35925203, -1.46929411],
#        [ 0.99288247,  0.40546467,  2.2901819 ],
#        [-1.00716855,  0.79762394,  0.75747245],
#        [ 0.99288247, -0.96709276, -0.31253226],
#        [ 0.99288247,  0.11134522,  0.75747245],
#        [ 0.99288247, -0.96709276,  0.55503912],
#        [ 0.99288247,  0.30742485,  0.06341534],
#        [ 0.99288247,  0.69958412, -1.26686079],
# ...

# %%
x_test_scale
# Out:
# array([[ 0.99288247, -0.77101313,  0.49720103],
#        [-1.00716855,  0.0133054 , -0.57280368],
#        [ 0.99288247, -0.28081405,  0.15017248],
#        [-1.00716855, -0.77101313,  0.26584866],
#        [-1.00716855, -0.28081405, -0.57280368],
#        [ 0.99288247, -1.06513258, -1.44037507],
#        [-1.00716855, -0.67297331, -1.5849703 ],
#        [ 0.99288247, -0.18277423,  2.14558666],
#        [-1.00716855, -1.94749093, -0.05226085],
#        [ 0.99288247,  0.89566375, -0.775237  ],
#        [ 0.99288247, -0.77101313, -0.60172273],
#        [-1.00716855, -0.96709276, -0.42820845],
#        [ 0.99288247, -0.08473441, -0.42820845],
#        [ 0.99288247,  0.11134522,  0.20801057],
#        [ 0.99288247, -1.7514113 ,  0.46828198],
#        [-1.00716855, -0.5749335 ,  1.36477242],
#        [ 0.99288247, -0.08473441,  0.20801057],
#        [ 0.99288247, -1.84945111,  0.43936294],
#        [-1.00716855,  1.67998229,  1.74072002],
#        [ 0.99288247, -0.28081405, -1.38253697],
# ...

# %%
from sklearn. preprocessing import MinMaxScaler
min_max = MinMaxScaler()

min_max.fit(X_train)
# Out:
# MinMaxScaler()

# %%
x_train_min_max_scale = min_max.transform(X_train)
x_test_min_max_scale = min_max.transform(X_test)

# %%
x_train_min_max_scale
# Out:
# array([[1.        , 0.19047619, 0.        ],
#        [1.        , 1.        , 0.64444444],
#        [0.        , 0.47619048, 0.71851852],
#        [1.        , 0.52380952, 0.68148148],
#        [0.        , 0.57142857, 0.28148148],
#        [1.        , 0.4047619 , 0.32592593],
#        [1.        , 0.71428571, 0.19259259],
#        [0.        , 0.71428571, 0.88148148],
#        [0.        , 0.47619048, 0.72592593],
#        [1.        , 0.26190476, 0.98518519],
#        [0.        , 0.19047619, 0.        ],
#        [1.        , 1.        , 0.2       ],
#        [1.        , 0.14285714, 0.02962963],
#        [1.        , 0.57142857, 0.99259259],
#        [0.        , 0.66666667, 0.6       ],
#        [1.        , 0.23809524, 0.32592593],
#        [1.        , 0.5       , 0.6       ],
#        [1.        , 0.23809524, 0.54814815],
#        [1.        , 0.54761905, 0.42222222],
#        [1.        , 0.64285714, 0.08148148],
#        [0.        , 0.35714286, 0.4       ],
# ...

# %%
x_test_min_max_scale
# Out:
# array([[1.        , 0.28571429, 0.53333333],
#        [0.        , 0.47619048, 0.25925926],
#        [1.        , 0.4047619 , 0.44444444],
#        [0.        , 0.28571429, 0.47407407],
#        [0.        , 0.4047619 , 0.25925926],
#        [1.        , 0.21428571, 0.03703704],
#        [0.        , 0.30952381, 0.        ],
#        [1.        , 0.42857143, 0.95555556],
#        [0.        , 0.        , 0.39259259],
#        [1.        , 0.69047619, 0.20740741],
#        [1.        , 0.28571429, 0.25185185],
#        [0.        , 0.23809524, 0.2962963 ],
#        [1.        , 0.45238095, 0.2962963 ],
#        [1.        , 0.5       , 0.45925926],
#        [1.        , 0.04761905, 0.52592593],
#        [0.        , 0.33333333, 0.75555556],
#        [1.        , 0.45238095, 0.45925926],
#        [1.        , 0.02380952, 0.51851852],
#        [0.        , 0.88095238, 0.85185185],
#        [1.        , 0.4047619 , 0.05185185],
#        [0.        , 0.4047619 , 0.23703704],
# ...

# %%
from sklearn.preprocessing import RobustScaler
rb = RobustScaler()

# %%
rb.fit(X_train)
# Out:
# RobustScaler()

# %%
x_train_rb = rb.transform(X_train)
x_test_rb = rb.transform(X_test)

# %%
x_train_rb
# Out:
# array([[ 0.        , -0.6875    , -1.23333333],
#        [ 0.        ,  1.4375    ,  0.7       ],
#        [-1.        ,  0.0625    ,  0.92222222],
#        [ 0.        ,  0.1875    ,  0.81111111],
#        [-1.        ,  0.3125    , -0.38888889],
#        [ 0.        , -0.125     , -0.25555556],
#        [ 0.        ,  0.6875    , -0.65555556],
#        [-1.        ,  0.6875    ,  1.41111111],
#        [-1.        ,  0.0625    ,  0.94444444],
#        [ 0.        , -0.5       ,  1.72222222],
#        [-1.        , -0.6875    , -1.23333333],
#        [ 0.        ,  1.4375    , -0.63333333],
#        [ 0.        , -0.8125    , -1.14444444],
#        [ 0.        ,  0.3125    ,  1.74444444],
#        [-1.        ,  0.5625    ,  0.56666667],
#        [ 0.        , -0.5625    , -0.25555556],
#        [ 0.        ,  0.125     ,  0.56666667],
#        [ 0.        , -0.5625    ,  0.41111111],
#        [ 0.        ,  0.25      ,  0.03333333],
#        [ 0.        ,  0.5       , -0.98888889],
# ...

# %%
x_test_rb
# Out:
# array([[ 0.        , -0.4375    ,  0.36666667],
#        [-1.        ,  0.0625    , -0.45555556],
#        [ 0.        , -0.125     ,  0.1       ],
#        [-1.        , -0.4375    ,  0.18888889],
#        [-1.        , -0.125     , -0.45555556],
#        [ 0.        , -0.625     , -1.12222222],
#        [-1.        , -0.375     , -1.23333333],
#        [ 0.        , -0.0625    ,  1.63333333],
#        [-1.        , -1.1875    , -0.05555556],
#        [ 0.        ,  0.625     , -0.61111111],
#        [ 0.        , -0.4375    , -0.47777778],
#        [-1.        , -0.5625    , -0.34444444],
#        [ 0.        ,  0.        , -0.34444444],
#        [ 0.        ,  0.125     ,  0.14444444],
#        [ 0.        , -1.0625    ,  0.34444444],
#        [-1.        , -0.3125    ,  1.03333333],
#        [ 0.        ,  0.        ,  0.14444444],
#        [ 0.        , -1.125     ,  0.32222222],
#        [-1.        ,  1.125     ,  1.32222222],
#        [ 0.        , -0.125     , -1.07777778],
# ...

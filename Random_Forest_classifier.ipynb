# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
print(df.isnull().sum())
print(df['State'].unique())
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64
# ['New York' 'California' 'Florida']

# %%
X= df.drop(columns='Profit')
y= df['Profit']

# %%
X = pd.get_dummies(data=X,columns=['State'],drop_first=True)
X = X.astype(int)

# %%
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0     165349          136897           471784              0               1
# 1     162597          151377           443898              0               0
# 2     153441          101145           407934              1               0
# 3     144372          118671           383199              0               1
# 4     142107           91391           366168              1               0

# %%
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print('shape of X_train is: ', X_train.shape)
print('shape of X_test is: ', X_test.shape)
print('shape of y_train is: ',y_train.shape)
print('shape of y_test is: ',y_test.shape)
# Out:
# shape of X_train is:  (40, 5)
# shape of X_test is:  (10, 5)
# shape of y_train is:  (40,)
# shape of y_test is:  (10,)

# %%
X_test
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 28      66051          182645           118148              1               0
# 11     100671           91790           249744              0               0
# 10     101913          110594           229160              1               0
# 41      27892           84710           164470              1               0
# 2      153441          101145           407934              1               0
# 27      72107          127864           353183              0               1
# 38      20229           65947           185265              0               1
# 31      61136          152701            88218              0               1
# 22      73994          122782           303319              1               0
# 4      142107           91391           366168              1               0

# %%
y_test
# Out:
# 28    103282.38
# 11    144259.40
# 10    146121.95
# 41     77798.83
# 2     191050.39
# 27    105008.31
# 38     81229.06
# 31     97483.56
# 22    110352.25
# 4     166187.94
# Name: Profit, dtype: float64

# %%
X_train.head()
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 33      55493          103057           214634              1               0
# 35      46014           85047           205517              0               1
# 26      75328          144135           134050              1               0
# 34      46426          157693           210797              0               0
# 18      91749          114175           294919              1               0

# %%
y_train.head()
# Out:
# 33     96778.92
# 35     96479.51
# 26    105733.54
# 34     96712.80
# 18    124266.90
# Name: Profit, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=0)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = rf.predict(X_test)
y_pred
# Out:
# array([103542.241 , 136225.4725, 137169.6087,  79704.8636, 183790.5512,
#        112954.7816,  70667.9612,  99182.1382, 111295.814 , 168094.7555])

# %%
train_accuracy = rf.predict(X_train)
train_accuracy
# Out:
# array([ 98042.9233,  95347.0295, 109483.46  ,  96055.8519, 126620.2441,
#        154344.902 , 138088.3364,  54754.8048,  42444.2159, 103268.6584,
#        133215.0665, 100033.0951,  98479.3949, 122009.945 ,  72123.6318,
#        114432.0179,  68657.6131, 147069.3822, 132435.5377, 105357.4674,
#        160546.356 , 127296.8295,  79740.3079,  26849.4675, 189779.9657,
#        137746.771 ,  91337.2666, 112704.2666, 152382.2067, 108767.9539,
#         85171.9846, 114516.3202, 124845.9748, 148217.8958,  84245.3277,
#         52382.6345, 175103.6065, 189662.5888,  39093.1343,  67219.6308])

# %%
from sklearn.metrics import r2_score, accuracy_score, mean_squared_error

# %%
r2_score_ = r2_score(y_test, y_pred)
r2_score_
# Out:
# 0.9700374289598385

# %%
r2_score(y_train,train_accuracy)
# Out:
# 0.9898164182488992

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 38318880.20802024

# %%
mean_squared_error(y_train, train_accuracy)
# Out:
# 16675318.862336874
